# %% [markdown]
# import pandas as pd

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('housing.csv')
display(data.head())
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
__meow__= \
"""
steps to follow:
1. import the dataset
2.it consist of 3 feature and a label, so breaking the data in feature and label portion
3. since the feature are already engineered, so there is no need
a. scaling feature , removing outliers, and generating new feture out of it
b. later we will, do feature engineering by making new feature later
4. since it is a regression problem, and consist of 3 feature so the hypithesis is 
h(x) = w0 + w1x1 + w2x2 + w3x3
5. we will also use the gradient descent to minimise the loss and finding optimal value of weight in each iteration 
6. since i am not going to use a classifier so , i have to make the algo by myself
7. the overfitting is removed by, on each iteration trainging the model with weights then finding the error too and
evaluating the valiues of weight too, before updating we also find error cost function on validation step
but not updating the values of weight based on validation step , this process is solely dependent on the training set

8.from the given different lossvalue of training snd validation set, select the one having very close error rate on 
both set, or in other words select one that do best on both the data sets
"""

# %%
__theory__ = \
"""
before this some theory is to check the visualisation of each feature to label plots(scatter , histogram,etc), solely 
to find wheather label actually depend on feature or not 
and analyse the problem ,is ther eis a better feature that can be made out of the given feature that define the problem
better than above fgiven features.


"""

# %%
print(data['RM']).mean()
print data['RM'].max()
print data['RM'].min()
#so data is mean oriented

print data['LSTAT'].mean()
print data['LSTAT'].max()
print data['LSTAT'].min()
# data is mean below oriented

print data['PTRATIO'].mean()
print data['PTRATIO'].max()
print data['PTRATIO'].min()
#mean above oriented 

print data['MEDV'].mean()
print data['MEDV'].max()
print data['MEDV'].min()
# data is mean oriented
# Out:
# 6.24028834356
# 8.398
# 3.5610000000000004
# 12.9396319018
# 37.97
# 1.98
# 18.5165644172
# 22.0
# 12.6
# 454342.944785
# 1024800.0
# 105000.0

# %%
# making the regression algo 
__ralgo__ = \
"""
1.select the hypothesis
2.iterate over training set , termination condn= (when training set error == validation set error and acceptable too)

    3. iterate over each training dataset value
        a. calculate the predicted value, calculate the error value 
    calculate the sum of error of. whole traing set, store in temp1 variable
    
    4. iterate over validation step dataset
        a. calculate the predicted value from above model and error too of each datapoint
    calculate the sum of error of whole validation set, store in temp2 variable
    
    update the value of all weight by gradient descent algo depending on cost function of training set only
    
    
"""

# %%
def ralgo(trainX, trainY, valX, valY):
    pass

# %%
feature = data.drop('MEDV', axis = 1)
label = data['MEDV']
trainX = feature[:int(0.7*len(feature))]
print 0.7 * len(feature)
valX = feature[342:len(feature)]
print len(valX)
trainY = label[:int(0.7*len(label))]
valY = label[342:len(feature)]
# Out:
# 342.3
# 147

# %%
#answer is not accuarte as feature are not scaled as per label range, so mean scaling is better option

w1, w2, w3, w = 40, 33, 33, -22
hx = w + w1*trainX['RM'] + w2*trainX['LSTAT']  + w3*trainX['PTRATIO']
#print hx , trainY
m = sum((hx-trainY)**2)

# %%
trainX['RM'] = (trainX['RM'] - trainX['RM'].mean())/len(trainX['RM'])
trainX

trainX['LSTAT'] = (trainX['LSTAT'] - trainX['LSTAT'].mean())/len(trainX['LSTAT'])
trainX

trainX['PTRATIO'] = (trainX['PTRATIO'] - trainX['PTRATIO'].mean())/len(trainX['PTRATIO'])
trainX
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
